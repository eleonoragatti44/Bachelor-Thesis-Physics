# %%
import os
import numpy as np
import pandas as pd
import glob
import matplotlib.pylab as plt
import seaborn as sns
import functions as f
# %matplotlib inline

# %% [markdown]
# ## Plots and Histograms

# %%
f.plot_from_path("./ErrorPlot")
# Out:
# ['Sigmoid', '3L', 'e']
# ['Tanh', '1L', 'co', 'max']
# ['Tanh', '1L', 'cx', 'max']
# ['Sigmoid', '2L', 'e']
# ['Sigmoid', '1L', 'cx', 'max']
# ['Sigmoid', '1L', 'co', 'max']
# ['Tanh', '3L', 'cx', 'max']
# ['Tanh', '3L', 'co', 'max']
# ['Sigmoid', '3L', 'co', 'max']
# ['Sigmoid', '3L', 'cx', 'max']
# ['Tanh', '1L', 'e']
# ['Sigmoid', '2L', 'cx', 'max']
# ['Sigmoid', '2L', 'co', 'max']
# ['Tanh', '2L', 'co', 'max']
# ['Tanh', '2L', 'cx', 'max']
# ['Tanh', '1L', 'fwhm', 'y']
# ['Sigmoid', '1L', 'fwhm', 'x']
# ['Tanh', '3L', 'e']
# ['Tanh', '1L', 'fwhm', 'x']
# ['Sigmoid', '1L', 'fwhm', 'y']
# ['Tanh', '2L', 'e']
# ['Tanh', '2L', 'fwhm', 'x']
# ['Sigmoid', '2L', 'fwhm', 'y']
# ['Sigmoid', '1L', 'e']
# ['Tanh', '2L', 'fwhm', 'y']
# ['Sigmoid', '2L', 'fwhm', 'x']
# ['Tanh', '3L', 'fwhm', 'y']
# ['Sigmoid', '3L', 'fwhm', 'x']
# ['Tanh', '3L', 'fwhm', 'x']
# ['Sigmoid', '3L', 'fwhm', 'y']

# %% [markdown]
# ## Violin Plots

# %%
df_e, df_fwhmx, df_fwhmy, df_comax, df_cxmax = f.df_from_path("./ErrorPlot")

# %%
# la funzione mod_df modifica il dataframe tale da ottenere una curva relativa all'interpolazione
#che sia la stessa per tutte le architetture
df_e_plot = f.mod_df(df_e)
df_fwhmx_plot = f.mod_df(df_fwhmx)
df_fwhmy_plot = f.mod_df(df_fwhmy)
df_comax_plot = f.mod_df(df_comax)
df_cxmax_plot = f.mod_df(df_cxmax)

# %%
f.violin_from_df(df_e_plot, "e")
f.violin_from_df(df_fwhmx_plot, "fwhmx")
f.violin_from_df(df_fwhmy_plot, "fwhmy")
f.violin_from_df(df_comax_plot, "comax")
f.violin_from_df(df_cxmax_plot, "cxmax")

# %%
def getstats(df):
    archs = ["Tanh_1L", "Tanh_2L", "Tanh_3L", "Sigmoid_1L", "Sigmoid_2L", "Sigmoid_3L"]
    for arch in archs:
        print(arch)
        filt = df.loc[df_e["architecture"] == arch]
        filt_net = filt.loc[ df_e["error"] == "[Net]"]
        print("Net\tMin, Med, Max: ", np.percentile(filt_net["value"], [5,50,95]))
        filt_int = filt.loc[ df_e["error"] == "[Int]"]
        print("Int\tMin, Med, Max: ", np.percentile(filt_int["value"], [5,50,95]), "\n")

# %%
getstats(df_e)
# Out:
# Tanh_1L
# Net	Min, Med, Max:  [0.00017087 0.00262415 0.01255571]
# Int	Min, Med, Max:  [0.00153072 0.00860882 0.02025677]
#
# Tanh_2L
# Net	Min, Med, Max:  [0.00022261 0.00164938 0.00734339]
# Int	Min, Med, Max:  [0.00023738 0.00929868 0.02138383]
#
# Tanh_3L
# Net	Min, Med, Max:  [0.00021777 0.00209427 0.01005057]
# Int	Min, Med, Max:  [0.00067408 0.00859118 0.02022829]
#
# Sigmoid_1L
# Net	Min, Med, Max:  [0.00048016 0.00218248 0.01008445]
# Int	Min, Med, Max:  [0.00088955 0.00818074 0.02238206]
#
# Sigmoid_2L
# Net	Min, Med, Max:  [0.00120826 0.01056588 0.02682105]
# Int	Min, Med, Max:  [0.00159529 0.00650752 0.01945316]
#
# Sigmoid_3L
# Net	Min, Med, Max:  [0.00042292 0.00284088 0.01121291]
# Int	Min, Med, Max:  [0.00184752 0.00824702 0.02184395]
