# %%
import os
import numpy as np
import pandas as pd
import glob
import matplotlib.pylab as plt
import seaborn as sns
import functions as f
# %matplotlib inline

# %% [markdown]
# ## Plots and Histograms

# %%
f.plot_from_path("./ErrorPlot")
# Out:
# ['Sigmoid', '3L', 'e']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a2bb3fa09ae8> in <module>
# ----> 1 f.plot_from_path("./ErrorPlot")
#
# ~/Desktop/Git Tesi/Neural Networks/Py/functions.py in plot_from_path(PATH)
#     274                 hist.set(xlabel="Error", ylabel="Count")
#     275             plot.set(xlabel = "Index", ylabel = "Error")
# --> 276             fig.savefig(f"./Plots/Hist/{Title_str}.png", bbox_inches='tight', dpi=600)
#     277             plt.show()
#     278
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...

# %% [markdown]
# ## Violin Plots

# %%
df_e, df_fwhmx, df_fwhmy, df_comax, df_cxmax, df_check = f.df_from_path("./ErrorPlot/Run1_complete")
#df_e, df_fwhmx, df_fwhmy, df_comax, df_cxmax = f.df_from_path("./ErrorPlot/Run4_complete")

# %%
# la funzione mod_df modifica il dataframe tale da ottenere una curva relativa all'interpolazione
#che sia la stessa per tutte le architetture
df_e_plot = f.mod_df(df_e)
df_fwhmx_plot = f.mod_df(df_fwhmx)
df_fwhmy_plot = f.mod_df(df_fwhmy)
df_comax_plot = f.mod_df(df_comax)
df_cxmax_plot = f.mod_df(df_cxmax)
df_check_plot = f.mod_df(df_check)

# %%
f.violin_from_df(df_e_plot, "e")
f.violin_from_df(df_fwhmx_plot, "fwhmx")
f.violin_from_df(df_fwhmy_plot, "fwhmy")
f.violin_from_df(df_comax_plot, "comax")
f.violin_from_df(df_cxmax_plot, "cxmax")

# %%
#df_check_plot = f.mod_df(df_check)
f.violin_from_df(df_check_plot, "check_e")
