# %%
import os
import numpy as np
import pandas as pd
import glob
import matplotlib.pylab as plt
import seaborn as sns
import functions as f
# %matplotlib inline

# %% [markdown]
# ## Plots and Histograms

# %%
f.plot_from_path("./ErrorPlot")

# %% [markdown]
# ## Violin Plots

# %%
df_e, df_fwhmx, df_fwhmy, df_comax = f.df_from_path("./ErrorPlot")
f.violin_from_df(df_e, "e")
f.violin_from_df(df_fwhmx, "fwhmx")
f.violin_from_df(df_fwhmy, "fwhmy")
f.violin_from_df(df_fwhmy, "comax")
