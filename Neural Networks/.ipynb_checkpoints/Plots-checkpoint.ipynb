# %%
import functions as f
# %matplotlib inline

f.plot_from_path("./ErrorPlot")

# %%
import os
import numpy as np
import pandas as pd
import glob
import matplotlib.pylab as plt
import seaborn as sns

path = "./ErrorPlot" # use your path
all_files = glob.glob(path + "/*")
col_names = ["Err Net", "Err Int"]
l_e = []
l_fwhmx = []
l_fwhmy = []

for filename in all_files:
    if "_e" in filename:  
        df = pd.read_csv(filename,
                         usecols=[0],
                         index_col=None, 
                         delimiter=" ", 
                         header=None, 
                         names=[os.path.basename(filename)])
        l_e.append(df)
    if "_fwhmx" in filename:
        df = pd.read_csv(filename,
                         #usecols=[0],
                         index_col=None, 
                         delimiter=" ", 
                         header=None, 
                         names=[os.path.basename(filename)])
        l_fwhmx.append(df)
    if "_fwhmy" in filename:
        df = pd.read_csv(filename,
                         usecols=[0],
                         index_col=None, 
                         delimiter=" ", 
                         header=None, 
                         names=[os.path.basename(filename)])
        l_fwhmy.append(df)

df_e = pd.concat(l_e, axis=1, sort=False)
df_fwhmx = pd.concat(l_fwhmx, axis=1, sort=False)
df_fwhmy = pd.concat(l_fwhmy, axis=1, sort=False)

# %%
sns.violinplot(data=df_e, palette="muted")

# %%
sns.violinplot(data=df_fwhmx, palette="muted")

# %%
sns.violinplot(data=df_fwhmy, palette="muted")
